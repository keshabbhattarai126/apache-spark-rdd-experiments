# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext

# %%
sc = SparkContext("local","WordCount")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# WARNING: package sun.security.action not in java.base
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/12 11:53:25 WARN Utils: Your hostname, Keshabs-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 10.1.24.84 instead (on interface en0)
# 26/05/12 11:53:25 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/12 11:53:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/05/12 11:53:27 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# WARNING: A terminally deprecated method in sun.misc.Unsafe has been called
# WARNING: sun.misc.Unsafe::arrayBaseOffset has been called by org.apache.spark.unsafe.Platform (file:/opt/homebrew/Cellar/apache-spark/4.1.1/libexec/jars/spark-unsafe_2.13-4.1.1.jar)
# WARNING: Please consider reporting this to the maintainers of class org.apache.spark.unsafe.Platform
# WARNING: sun.misc.Unsafe::arrayBaseOffset will be removed in a future release

# %%
lines = sc.parallelize([
    "hello world",
    "hello spark",
    "spark is great",
    "hello world again"
])

# %%
lines.getNumPartitions()
# Out:
# 1

# %%
word_counts = (
    lines.flatMap(lambda line: line.split(" "))
         .map(lambda word: (word, 1))
         .reduceByKey(lambda a, b: a + b)
)

# %%
print(word_counts.collect())
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# [('hello', 3), ('world', 2), ('spark', 2), ('is', 1), ('great', 1), ('again', 1)]

# %%
for word, count in sorted(word_counts.collect()):print(f"{word}:{count}")
# Out:
# again:1
# great:1
# hello:3
# is:1
# spark:2
# world:2

# %%
sc.stop()
