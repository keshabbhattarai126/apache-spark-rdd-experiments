# %% [markdown]
# ## Import Pyspark Libraries and Create Spark Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType

# %%
spark = SparkSession.builder.appName("Data Analysis").master("local[*]").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/24 11:26:56 WARN Utils: Your hostname, Keshabs-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 10.1.24.84 instead (on interface en0)
# 26/05/24 11:26:56 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/24 11:26:56 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/05/24 11:26:57 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %% [markdown]
# ## Load / Import Data

# %%
df = spark.read.csv("employees.csv", header = True, inferSchema = True)

'''
schema = StructType([
StructField("id",IntegerType(),nullable = False)
])
'''

# json = spark.read.json()
# spark.read.parquet()

# %%
print(df)
# Out:
# DataFrame[id: int, name: string, department: string, salary: int, age: int]

# %%
df.show()
# Out:
# +---+-----+-----------+------+----+
# | id| name| department|salary| age|
# +---+-----+-----------+------+----+
# |  1|Alice|Engineering| 85000|  29|
# |  2|  Bob|  Marketing| 62000|  34|
# |  3|Carol|Engineering| 91000|  41|
# |  4|David|         HR|  NULL|  27|
# |  5|  Eve|  Marketing| 70000|  38|
# |  6|Frank|       NULL| 54000|NULL|
# |  7|Grace|Engineering| 95000|  35|
# |  8|Henry|         HR| 58000|  45|
# |  9|  Ivy|  Marketing| 67000|  31|
# | 10| Jack|Engineering| 78000|  28|
# +---+-----+-----------+------+----+

# %%
df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- age: integer (nullable = true)

# %%
df.dtypes
# Out:
# [('id', 'int'),
#  ('name', 'string'),
#  ('department', 'string'),
#  ('salary', 'int'),
#  ('age', 'int')]

# %% [markdown]
# ## Check for any null values

# %%
from pyspark.sql.functions import col,sum as spark_sum, isnan, when

# %%
# Using F.sum, F.when, and F.col based on your earlier imports
null_counts = df.select([
    F.sum(F.when(F.col(c).isNull(), 1).otherwise(0)).alias(c)
    for c in df.columns
])

# %%
null_counts.show()
# Out:
# +---+----+----------+------+---+
# | id|name|department|salary|age|
# +---+----+----------+------+---+
# |  0|   0|         1|     1|  1|
# +---+----+----------+------+---+

# %%
df.filter(col("salary").isNull()).show()
# Out:
# +---+-----+----------+------+---+
# | id| name|department|salary|age|
# +---+-----+----------+------+---+
# |  4|David|        HR|  NULL| 27|
# +---+-----+----------+------+---+

# %%
df.filter(col("name").isNull()).show()
# Out:
# +---+----+----------+------+---+
# | id|name|department|salary|age|
# +---+----+----------+------+---+
# +---+----+----------+------+---+

# %%
df_clean = df.dropna()
df_clean.show()
# Out:
# +---+-----+-----------+------+---+
# | id| name| department|salary|age|
# +---+-----+-----------+------+---+
# |  1|Alice|Engineering| 85000| 29|
# |  2|  Bob|  Marketing| 62000| 34|
# |  3|Carol|Engineering| 91000| 41|
# |  5|  Eve|  Marketing| 70000| 38|
# |  7|Grace|Engineering| 95000| 35|
# |  8|Henry|         HR| 58000| 45|
# |  9|  Ivy|  Marketing| 67000| 31|
# | 10| Jack|Engineering| 78000| 28|
# +---+-----+-----------+------+---+

# %%
df_filled = df.fillna({"salary": 0, "department": "Unknown"})

df_filled.show()
# Out:
# +---+-----+-----------+------+----+
# | id| name| department|salary| age|
# +---+-----+-----------+------+----+
# |  1|Alice|Engineering| 85000|  29|
# |  2|  Bob|  Marketing| 62000|  34|
# |  3|Carol|Engineering| 91000|  41|
# |  4|David|         HR|     0|  27|
# |  5|  Eve|  Marketing| 70000|  38|
# |  6|Frank|    Unknown| 54000|NULL|
# |  7|Grace|Engineering| 95000|  35|
# |  8|Henry|         HR| 58000|  45|
# |  9|  Ivy|  Marketing| 67000|  31|
# | 10| Jack|Engineering| 78000|  28|
# +---+-----+-----------+------+----+

# %%
df.describe().show()
# Out:
# +-------+------------------+-----+-----------+-----------------+-----------------+
# |summary|                id| name| department|           salary|              age|
# +-------+------------------+-----+-----------+-----------------+-----------------+
# |  count|                10|   10|          9|                9|                9|
# |   mean|               5.5| NULL|       NULL|73333.33333333333|34.22222222222222|
# | stddev|3.0276503540974917| NULL|       NULL|14696.93845669907|6.180165405913052|
# |    min|                 1|Alice|Engineering|            54000|               27|
# |    max|                10| Jack|  Marketing|            95000|               45|
# +-------+------------------+-----+-----------+-----------------+-----------------+
# 26/05/24 11:43:44 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
df.describe("salary").show()
# Out:
# +-------+-----------------+
# |summary|           salary|
# +-------+-----------------+
# |  count|                9|
# |   mean|73333.33333333333|
# | stddev|14696.93845669907|
# |    min|            54000|
# |    max|            95000|
# +-------+-----------------+

# %%
# Selecting Columns
df.select("name").show()
# Out:
# +-----+
# | name|
# +-----+
# |Alice|
# |  Bob|
# |Carol|
# |David|
# |  Eve|
# |Frank|
# |Grace|
# |Henry|
# |  Ivy|
# | Jack|
# +-----+

# %%
df.select(col("name"),col("salary"),col("department")).show()
# Out:
# +-----+------+-----------+
# | name|salary| department|
# +-----+------+-----------+
# |Alice| 85000|Engineering|
# |  Bob| 62000|  Marketing|
# |Carol| 91000|Engineering|
# |David|  NULL|         HR|
# |  Eve| 70000|  Marketing|
# |Frank| 54000|       NULL|
# |Grace| 95000|Engineering|
# |Henry| 58000|         HR|
# |  Ivy| 67000|  Marketing|
# | Jack| 78000|Engineering|
# +-----+------+-----------+

# %%
df.select(
    col("name"), 
    col("salary"), 
    (col("salary") * 2).alias("salary_with_bonus")
).show()
# Out:
# +-----+------+-----------------+
# | name|salary|salary_with_bonus|
# +-----+------+-----------------+
# |Alice| 85000|           170000|
# |  Bob| 62000|           124000|
# |Carol| 91000|           182000|
# |David|  NULL|             NULL|
# |  Eve| 70000|           140000|
# |Frank| 54000|           108000|
# |Grace| 95000|           190000|
# |Henry| 58000|           116000|
# |  Ivy| 67000|           134000|
# | Jack| 78000|           156000|
# +-----+------+-----------------+

# %%
df = df.withColumn("salary_band",
                   when(col("salary") >= 80000, "High")
                   .when(col("salary") >= 60000, "Mid")
                   .otherwise("low")
                  )
df.show()
# Out:
# +---+-----+-----------+------+----+-----------+
# | id| name| department|salary| age|salary_band|
# +---+-----+-----------+------+----+-----------+
# |  1|Alice|Engineering| 85000|  29|       High|
# |  2|  Bob|  Marketing| 62000|  34|        Mid|
# |  3|Carol|Engineering| 91000|  41|       High|
# |  4|David|         HR|  NULL|  27|        low|
# |  5|  Eve|  Marketing| 70000|  38|        Mid|
# |  6|Frank|       NULL| 54000|NULL|        low|
# |  7|Grace|Engineering| 95000|  35|       High|
# |  8|Henry|         HR| 58000|  45|        low|
# |  9|  Ivy|  Marketing| 67000|  31|        Mid|
# | 10| Jack|Engineering| 78000|  28|        Mid|
# +---+-----+-----------+------+----+-----------+

# %%
# Rows Selection

df.filter(col("salary") > 65000).show()
# Out:
# +---+-----+-----------+------+---+-----------+
# | id| name| department|salary|age|salary_band|
# +---+-----+-----------+------+---+-----------+
# |  1|Alice|Engineering| 85000| 29|       High|
# |  3|Carol|Engineering| 91000| 41|       High|
# |  5|  Eve|  Marketing| 70000| 38|        Mid|
# |  7|Grace|Engineering| 95000| 35|       High|
# |  9|  Ivy|  Marketing| 67000| 31|        Mid|
# | 10| Jack|Engineering| 78000| 28|        Mid|
# +---+-----+-----------+------+---+-----------+

# %%
df.filter(col("department") == "Engineering").show()
# Out:
# +---+-----+-----------+------+---+-----------+
# | id| name| department|salary|age|salary_band|
# +---+-----+-----------+------+---+-----------+
# |  1|Alice|Engineering| 85000| 29|       High|
# |  3|Carol|Engineering| 91000| 41|       High|
# |  7|Grace|Engineering| 95000| 35|       High|
# | 10| Jack|Engineering| 78000| 28|        Mid|
# +---+-----+-----------+------+---+-----------+

# %%
df.where(col("department") == "Engineering").show()
# Out:
# +---+-----+-----------+------+---+-----------+
# | id| name| department|salary|age|salary_band|
# +---+-----+-----------+------+---+-----------+
# |  1|Alice|Engineering| 85000| 29|       High|
# |  3|Carol|Engineering| 91000| 41|       High|
# |  7|Grace|Engineering| 95000| 35|       High|
# | 10| Jack|Engineering| 78000| 28|        Mid|
# +---+-----+-----------+------+---+-----------+

# %%
df.where(col("salary") > 65000).show()
# Out:
# +---+-----+-----------+------+---+-----------+
# | id| name| department|salary|age|salary_band|
# +---+-----+-----------+------+---+-----------+
# |  1|Alice|Engineering| 85000| 29|       High|
# |  3|Carol|Engineering| 91000| 41|       High|
# |  5|  Eve|  Marketing| 70000| 38|        Mid|
# |  7|Grace|Engineering| 95000| 35|       High|
# |  9|  Ivy|  Marketing| 67000| 31|        Mid|
# | 10| Jack|Engineering| 78000| 28|        Mid|
# +---+-----+-----------+------+---+-----------+

# %%
df.where((col("age") > 40) & (col("salary") > 60000)).show()
# Out:
# +---+-----+-----------+------+---+-----------+
# | id| name| department|salary|age|salary_band|
# +---+-----+-----------+------+---+-----------+
# |  3|Carol|Engineering| 91000| 41|       High|
# +---+-----+-----------+------+---+-----------+

# %%
df.limit(3).show()
# Out:
# +---+-----+-----------+------+---+-----------+
# | id| name| department|salary|age|salary_band|
# +---+-----+-----------+------+---+-----------+
# |  1|Alice|Engineering| 85000| 29|       High|
# |  2|  Bob|  Marketing| 62000| 34|        Mid|
# |  3|Carol|Engineering| 91000| 41|       High|
# +---+-----+-----------+------+---+-----------+

# %%
df_1 =df

# %%
df_1.show()
# Out:
# +---+-----+-----------+------+----+-----------+
# | id| name| department|salary| age|salary_band|
# +---+-----+-----------+------+----+-----------+
# |  1|Alice|Engineering| 85000|  29|       High|
# |  2|  Bob|  Marketing| 62000|  34|        Mid|
# |  3|Carol|Engineering| 91000|  41|       High|
# |  4|David|         HR|  NULL|  27|        low|
# |  5|  Eve|  Marketing| 70000|  38|        Mid|
# |  6|Frank|       NULL| 54000|NULL|        low|
# |  7|Grace|Engineering| 95000|  35|       High|
# |  8|Henry|         HR| 58000|  45|        low|
# |  9|  Ivy|  Marketing| 67000|  31|        Mid|
# | 10| Jack|Engineering| 78000|  28|        Mid|
# +---+-----+-----------+------+----+-----------+

# %%
df_1.filter(col("department") != "HR").show()
# Out:
# +---+-----+-----------+------+---+-----------+
# | id| name| department|salary|age|salary_band|
# +---+-----+-----------+------+---+-----------+
# |  1|Alice|Engineering| 85000| 29|       High|
# |  2|  Bob|  Marketing| 62000| 34|        Mid|
# |  3|Carol|Engineering| 91000| 41|       High|
# |  5|  Eve|  Marketing| 70000| 38|        Mid|
# |  7|Grace|Engineering| 95000| 35|       High|
# |  9|  Ivy|  Marketing| 67000| 31|        Mid|
# | 10| Jack|Engineering| 78000| 28|        Mid|
# +---+-----+-----------+------+---+-----------+

# %%
df_1.filter((col("department") != "HR") & (col("department") != "Marketing")).show()
# Out:
# +---+-----+-----------+------+---+-----------+
# | id| name| department|salary|age|salary_band|
# +---+-----+-----------+------+---+-----------+
# |  1|Alice|Engineering| 85000| 29|       High|
# |  3|Carol|Engineering| 91000| 41|       High|
# |  7|Grace|Engineering| 95000| 35|       High|
# | 10| Jack|Engineering| 78000| 28|        Mid|
# +---+-----+-----------+------+---+-----------+

# %%
# df_1.withColumnRenamed("salary",

# %%
# Change the column name of entire table
new_names = ["emp_id", "full_name", "dept", "pay", "years", "s_band"]
df_2 = df_1.toDF(*new_names).show()
# Out:
# +------+---------+-----------+-----+-----+------+
# |emp_id|full_name|       dept|  pay|years|s_band|
# +------+---------+-----------+-----+-----+------+
# |     1|    Alice|Engineering|85000|   29|  High|
# |     2|      Bob|  Marketing|62000|   34|   Mid|
# |     3|    Carol|Engineering|91000|   41|  High|
# |     4|    David|         HR| NULL|   27|   low|
# |     5|      Eve|  Marketing|70000|   38|   Mid|
# |     6|    Frank|       NULL|54000| NULL|   low|
# |     7|    Grace|Engineering|95000|   35|  High|
# |     8|    Henry|         HR|58000|   45|   low|
# |     9|      Ivy|  Marketing|67000|   31|   Mid|
# |    10|     Jack|Engineering|78000|   28|   Mid|
# +------+---------+-----------+-----+-----+------+

# %%
df_1.orderBy(col("salary").desc()).show()
# Out:
# +---+-----+-----------+------+----+-----------+
# | id| name| department|salary| age|salary_band|
# +---+-----+-----------+------+----+-----------+
# |  7|Grace|Engineering| 95000|  35|       High|
# |  3|Carol|Engineering| 91000|  41|       High|
# |  1|Alice|Engineering| 85000|  29|       High|
# | 10| Jack|Engineering| 78000|  28|        Mid|
# |  5|  Eve|  Marketing| 70000|  38|        Mid|
# |  9|  Ivy|  Marketing| 67000|  31|        Mid|
# |  2|  Bob|  Marketing| 62000|  34|        Mid|
# |  8|Henry|         HR| 58000|  45|        low|
# |  6|Frank|       NULL| 54000|NULL|        low|
# |  4|David|         HR|  NULL|  27|        low|
# +---+-----+-----------+------+----+-----------+

# %%
df_1.groupBy("department").agg(F.count("salary").alias("avg_salary")).show()
# Out:
# +-----------+----------+
# | department|avg_salary|
# +-----------+----------+
# |Engineering|         4|
# |         HR|         1|
# |       NULL|         1|
# |  Marketing|         3|
# +-----------+----------+

# %%
df_2 = df_1.dropna()

# %%
df_2.write.csv("output/employees_clean",header = True, mode = "overwrite")

# %%
spark.stop()
